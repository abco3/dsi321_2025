# %%
import pandas as pd

storage_options = {
    "key": "access_key",
    "secret": "secret_key",
    "client_kwargs": {
        "endpoint_url": "http://lakefs-dev:8000/"
    }
}

path_all_partition = 's3a://dust-concentration/main/dust_data.parquet'

df = pd.read_parquet(
    path=path_all_partition,
    storage_options=storage_options
)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          160 non-null    int64
#  1   timestamp      160 non-null    object
#  2   stationID      160 non-null    object
#  3   nameTH         160 non-null    object
#  4   areaTH         160 non-null    object
#  5   district       160 non-null    object
#  6   lat            160 non-null    object
#  7   long           160 non-null    object
#  8   AQI.aqi        160 non-null    int64
#  9   AQI.color_id   160 non-null    int64
#  10  PM25.value     160 non-null    float64
#  11  PM25.color_id  160 non-null    int64
#  12  PM10.value     160 non-null    int64
#  13  PM10.color_id  160 non-null    int64
#  14  O3.value       160 non-null    int64
#  15  NO2.value      160 non-null    int64
#  16  CO.value       160 non-null    float64
# ...
