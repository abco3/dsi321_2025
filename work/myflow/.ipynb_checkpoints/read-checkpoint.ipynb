# %%
import pandas as pd

storage_options = {
    "key": "access_key",
    "secret": "secret_key",
    "client_kwargs": {
        "endpoint_url": "http://lakefs-dev:8000/"
    }
}

path_all_partition = 's3a://pollution/main/pollution_data.parquet'

df = pd.read_parquet(
    path=path_all_partition,
    storage_options=storage_options
)

df.info()
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 13
#       3 storage_options = {
#       4     "key": "access_key",
#       5     "secret": "secret_key",
#    (...)      8     }
#       9 }
#      11 path_all_partition = 's3a://pollution/main/pollution_data.parquet'
# ---> 13 df = pd.read_parquet(
#      14     path=path_all_partition,
#      15     storage_options=storage_options
#      16 )
#      18 df.info()
#      19 df.head()
#
# File /usr/local/lib/python3.11/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
# ...
